# %%
import seaborn as sns
import pandas as pd

week = {"Days":[1,2,3,4,5],
"NOP" : [50,40, 60,30,44]}
df = pd.DataFrame(week)
print(df)

sns.lineplot(data=week,x="Days",y="NOP")
# Out:
#    Days  NOP
# 0     1   50
# 1     2   40
# 2     3   60
# 3     4   30
# 4     5   44
# <Axes: xlabel='Days', ylabel='NOP'>

# %%
data = pd.read_excel("employees.xlsx")
# print(data)
sns.lineplot(data=data,x="Job Title",y="Age",hue="Ethnicity",style="City")
# Out:
# <Axes: xlabel='Job Title', ylabel='Age'>
