# %%
import matplotlib.pyplot as plt

x =[1, 2, 3, 4,5]
y = [45,34,56, 23,45]
plt.subplot (2,3,1)
plt.plot(x,y)
x= [5,6,7,8,9]
У = [67,50,66,56,82]
plt.subplot (2,3,2)
plt.bar(x,y)
x = [2,4,6,8, 10]
у = [57,50,60,55,20]
plt.subplot (2,3,3)
plt.stem(x,y)
plt.suptitle("idk wtf am i doing")
plt.show()
