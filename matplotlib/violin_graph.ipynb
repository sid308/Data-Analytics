# %%
import matplotlib.pyplot as plt
import pandas as pd
a = [20,30,40,50,0,30,40,40, 30,30,70,80, 70,75,80,82, 88,40,20]
plt. violinplot(a, showmedians = True)
plt. show()

# %%
data = pd.read_excel("employees.xlsx")
df=pd.DataFrame(data)
print(df)
plt.violinplot(df["Annual Salary"],showmedians=True)
plt.show()
# Out:
#       EEID        Full Name                 Job Title       Department  \
# 0   E02387      Emily Davis                Sr. Manger               IT
# 1   E04105    Theodore Dinh       Technical Architect               IT
# 2   E02572     Luna Sanders                  Director          Finance
# 3   E02832  Penelope Jordan  Computer Systems Manager               IT
# 4   E01639        Austin Vo               Sr. Analyst          Finance
# 5   E00644     Joshua Gupta    Account Representative            Sales
# 6   E01550      Ruby Barnes                   Manager               IT
# 7   E04332      Luke Martin                   Analyst          Finance
# 8   E04533    Easton Bailey                   Manager       Accounting
# 9   E03838  Madeline Walker               Sr. Analyst          Finance
# 10  E00591     Savannah Ali                Sr. Manger  Human Resources
# 11  E03344    Camila Rogers         Controls Engineer      Engineering
# 12  E00530        Eli Jones                   Manager  Human Resources
# 13  E04239     Everleigh Ng                Sr. Manger          Finance
# 14  E03496      Robert Yang               Sr. Analyst       Accounting
# 15  E00549      Isabella Xi            Vice President        Marketing
# 16  E00163     Bella Powell                  Director          Finance
# 17  E00884     Camila Silva                Sr. Manger        Marketing
# 18  E04116     David Barnes                  Director               IT
#
#     Gender  Ethnicity  Age  Annual Salary  Bonus %        Country       City
# 0   Female      Black   55         141604     0.15  United States    Seattle
# 1     Male      Asian   59          99975     0.00          China  Chongqing
# 2   Female  Caucasian   50         163099     0.20  United States    Chicago
# 3   Female  Caucasian   26          84913     0.07  United States    Chicago
# 4     Male      Asian   55          95409     0.00  United States    Phoenix
# 5     Male      Asian   57          50994     0.00          China  Chongqing
# 6   Female  Caucasian   27         119746     0.10  United States    Phoenix
# 7     Male      Black   25          41336     0.00  United States      Miami
# 8     Male  Caucasian   29         113527     0.06  United States     Austin
# 9   Female  Caucasian   34          77203     0.00  United States    Chicago
# 10  Female      Asian   36         157333     0.15  United States      Miami
# 11  Female  Caucasian   27         109851     0.00  United States    Seattle
# 12    Male  Caucasian   59         105086     0.09  United States     Austin
# 13  Female      Asian   51         146742     0.10          China   Shanghai
# 14    Male      Asian   31          97078     0.00  United States     Austin
# 15  Female      Asian   41         249270     0.30  United States    Seattle
# 16  Female      Black   65         175837     0.20  United States    Phoenix
# 17  Female     Latino   64         154828     0.13  United States    Seattle
# 18    Male  Caucasian   64         186503     0.24  United States   Columbus
