# %%
import matplotlib.pyplot as plt
import pandas as pd

x = [10,40,20,40,20,40,20,40,60,70,50,40]
plt.stem(x,linefmt="--",markerfmt="*",bottom=0,basefmt="--",orientation='horizontal')
plt.show()

# %%
data = pd.read_excel("employees.xlsx")
df=pd.DataFrame(data)
# print(df)

plt.stem(df["Annual Salary"],linefmt="--")
plt.plot(df["Annual Salary"])
plt.show()
