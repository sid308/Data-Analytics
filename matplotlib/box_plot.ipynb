# %%
import matplotlib.pyplot as plt

l = [1,3,4,7,12,2,8,9,24]
l1 = [12,8,6,3,8,14,24]
# l.sort()
plot_values=[l,l1]
print(l)

plt.boxplot(plot_values)
plt.show()
# Out:
# [1, 3, 4, 7, 12, 2, 8, 9, 24]
